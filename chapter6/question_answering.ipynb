# %% [markdown]
# # Question-answering multiple choice questions

# %% [markdown]
# Firts, let's download a public MMLU [dataset](https://huggingface.co/datasets/cais/mmlu) from HuggingFace:

# %%
from datasets import load_dataset
ds = load_dataset("cais/mmlu", "high_school_geography")
# Out:
# README.md:   0%|          | 0.00/53.2k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/138k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/28.2k [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/6.16k [00:00<?, ?B/s]
# dev-00000-of-00001.parquet:   0%|          | 0.00/3.93k [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/198 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/22 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/5 [00:00<?, ? examples/s]

# %% [markdown]
# We can explore the dataset:

# %%
ds_dict = ds["test"].take(100).to_dict()
print(ds_dict["question"][0])
# Out:
# The main factor preventing subsistence economies from advancing economically is the lack of

# %%
print(ds_dict["choices"][0])
# Out:
# ['a currency.', 'a well-connected transportation infrastructure.', 'government activity.', 'a banking service.']

# %%
ds_dict["choices"][0][ds_dict["answer"][0]]
# Out:
# 'a well-connected transportation infrastructure.'

# %% [markdown]
# Now, let's create our research agent (pay attention to how we put together the system prompt by describing the agent's profile!):

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm_small = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)
# Out:
# /home/ben/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
from langchain_community.agent_toolkits.load_tools import load_tools
from langgraph.prebuilt import create_react_agent


research_tools = load_tools(
  tool_names=["ddg-search", "arxiv", "wikipedia"],
  llm=llm_small
)

system_prompt = (
    "You're a hard-working, curious and creative student. "
    "You're working on exam quesion. Think step by step."
    "Always provide an argumentation for your answer. "
    "Do not assume anything, use available tools to search "
    "for evidence and supporting statements."
)

# %%
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langgraph.graph import MessagesState
from langgraph.prebuilt.chat_agent_executor import AgentState

raw_prompt_template = (
    "Answer the following multiple-choice question. "
    "\nQUESTION:\n{question}\n\nANSWER OPTIONS:\n{options}\n"
)
prompt = ChatPromptTemplate.from_messages(
    [("system", system_prompt),
     ("user", raw_prompt_template),
     ("placeholder", "{messages}")
     ]
)

class ResearchState(AgentState):
  question: str
  options: str

research_agent = create_react_agent(model=llm_small, tools=research_tools, state_schema=ResearchState, prompt=prompt)

# %% [markdown]
# Now we define another agent that reflects on the anwer and provides critique:

# %%
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate


raw_prompt_template_with_critique = (
    "You tried to answer the exam question and you get feedback from your "
    "professor. Work on improving your answer and incorporating the feedback. "
    "\nQUESTION:\n{question}\n\nANSWER OPTIONS:\n{options}\n\n"
    "INITIAL ANSWER:\n{answer}\n\nFEEDBACK:\n{feedback}"

)
prompt = ChatPromptTemplate.from_messages(
    [("system", system_prompt),
     ("user", raw_prompt_template_with_critique),
     ("placeholder", "{messages}")
     ]
)

class ReflectionState(ResearchState):
  answer: str
  feedback: str

research_agent_with_critique = create_react_agent(model=llm_small, tools=research_tools, state_schema=ReflectionState, prompt=prompt)

# %%
from pydantic import BaseModel, Field
from typing import Optional

reflection_prompt = (
    "You are a university professor and you're supervising a student who is "
    "working on multiple-choice exam question. "
    "nQUESTION: {question}.\nANSWER OPTIONS:\n{options}\n."
    "STUDENT'S ANSWER:\n{answer}\n"
    "Reflect on the answer and provide a feedback whether the answer "
    "is right or wrong. If you think the final answer is correct, reply with "
    "the final answer. Only provide critique if you think the asnwer might "
    "be incorrect or there are reasoning flaws. Do not assume anything, "
    "evaluate only the reasoning the student provided and whether there is "
    "enough evidence for their answer."
)

class Response(BaseModel):
    """A final response to the user."""

    answer: Optional[str] = Field(
        description="The final answer. It should be empty if critique has been provided.",
        default=None,
    )
    critique: Optional[str] = Field(
        description="A critique of the initial answer. If you think it might be incorrect, provide an acitonable feedback",
        default=None,
    )

# %% [markdown]
# Let's put everything together and create a multi-agent system:

# %%
from typing import Annotated, Literal, TypedDict
from langchain_core.runnables.config import RunnableConfig
from operator import add
from langgraph.graph import StateGraph, START, END


class ReflectionAgentState(TypedDict):
    question: str
    options: str
    answer: str
    steps: Annotated[int, add]
    response: Response


def _should_end(state: ReflectionAgentState, config: RunnableConfig) -> Literal["research", END]:
    max_reasoning_steps = config["configurable"].get("max_reasoning_steps", 10)
    if state.get("response") and state["response"].answer:
        return END
    if state.get("steps", 1) > max_reasoning_steps:
        return END
    return "research"

reflection_chain = PromptTemplate.from_template(reflection_prompt) | llm_small.with_structured_output(Response)

def _reflection_step(state):
    result = reflection_chain.invoke(state)
    return {"response": result, "steps": 1}


def _research_start(state):
  answer = research_agent.invoke(state)
  return {"answer": answer["messages"][-1].content}


def _research(state):
  agent_state = {
      "answer": state["answer"],
      "question": state["question"],
      "options": state["options"],
      "feedback": state["response"].critique
  }
  answer = research_agent_with_critique.invoke(agent_state)
  return {"answer": answer["messages"][-1].content}

# %%
builder = StateGraph(ReflectionAgentState)
builder.add_node("research_start", _research_start)
builder.add_node("research", _research)
builder.add_node("reflect", _reflection_step)

builder.add_edge(START, "research_start")
builder.add_edge("research_start", "reflect")
builder.add_edge("research", "reflect")
builder.add_conditional_edges("reflect", _should_end)
graph = builder.compile()


from IPython.display import Image, display
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take a random question and run our agent:

# %%
i = 3
question = ds_dict["question"][i]
options = "\n".join([f"{i}. {a}" for i, a in enumerate(ds_dict["choices"][i])])

async for _, event in graph.astream({"question": question, "options": options}, stream_mode=["updates"]):
  print(event)
# Out:
# /home/ben/anaconda3/envs/langchain_ai/lib/python3.10/site-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# {'research_start': {'answer': 'Based on the information from Wikipedia, the zone described in the question is the "Zone of Transition". This zone is characterized by residential deterioration and encroachment by business and light manufacturing, making it the area where low-income slums, ethnic ghettos, and general deterioration are most likely to be found. Therefore, the answer is the second zone.\n\n**Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique='The student\'s answer is based on the "Zone of Transition", which aligns with the characteristics described in the question. However, the question asks for the zone number, and the student correctly identifies it as the second zone. Therefore, the final answer is correct.'), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand the feedback. The initial answer was correct, but I need to make sure I\'m clearly stating the zone number in the final answer.\n\nHere\'s the improved answer:\n\nBased on the characteristics described in the question—low-income slums, ethnic ghettos, and general deterioration—this corresponds to the "Zone of Transition" in Burgess\'s concentric zone model. This zone is the second zone.\n\n**Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student correctly identifies the zone containing low-income slums, ethnic ghettos, and general deterioration as the 'Zone of Transition'. However, the student states that this is the second zone, which is correct. The answer is therefore correct."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand. The feedback confirms my understanding of the Burgess model. The "Zone of Transition" is indeed the correct answer, and it\'s the second zone.\n\nHere\'s the final, improved answer:\n\nThe zone containing low-income slums, ethnic ghettos, and general deterioration in Burgess\'s concentric zone model is the **second** zone, also known as the "Zone of Transition."\n\n**Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique='The student correctly identifies the Zone of Transition as the area with low-income slums, ethnic ghettos, and general deterioration. The reasoning is sound. The answer is correct.'), 'steps': 1}}
# {'research': {'answer': 'The feedback confirms that the initial answer is correct. The question asks about the zone in Burgess\'s model that contains low-income slums, ethnic ghettos, and general deterioration. The initial answer correctly identifies this as the "Zone of Transition," which is the second zone.\n\nTherefore, the improved answer remains the same, simply restating the correct information for clarity.\n\n**Final Answer:**\n\nThe zone containing low-income slums, ethnic ghettos, and general deterioration in Burgess\'s concentric zone model is the **second** zone, also known as the "Zone of Transition."\n\n**Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student correctly identifies the 'Zone of Transition' as the area with low-income slums, etc. However, the student should clearly link the Zone of Transition to the 'second' zone. The answer is correct, but the explanation could be more explicit about the direct correlation between the zone and the answer option."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand the feedback. The professor wants a more explicit connection between the answer option (the number) and the zone description. Here\'s the revised answer:\n\n**Improved Answer:**\n\nThe Burgess concentric zone model describes urban areas as a series of concentric rings. The zone that typically contains low-income slums, ethnic ghettos, and areas of general deterioration is the **second** zone. This zone, often called the "Zone of Transition," is characterized by these features due to its location adjacent to the central business district (the first zone) and its history of industrial encroachment and the resulting influx of transient populations. The second zone is characterized by these features.\n\n**Final Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student correctly identifies the second zone as the one containing low-income slums, ethnic ghettos, and deterioration. However, the reasoning could be slightly more precise. While the proximity to the central business district and industrial encroachment are contributing factors, the key characteristic of the 'Zone of Transition' is its constant state of change, with waves of immigrants and migrants leading to overcrowding and decline. The provided answer is a good answer. I will provide the final answer as is."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand the feedback. The professor acknowledges the correct answer (1) but suggests a more nuanced explanation. Here\'s a further improved answer:\n\n**Improved Answer:**\n\nThe Burgess concentric zone model depicts urban areas as a series of concentric rings. The zone that typically contains low-income slums, ethnic ghettos, and areas of general deterioration is the **second** zone. This zone, often called the "Zone of Transition," is characterized by a high degree of flux. Its location adjacent to the central business district (the first zone) and industrial encroachment are contributing factors. However, the key defining characteristic is the constant state of change. Waves of immigrants and migrants, along with the resulting overcrowding and decline, lead to the concentration of these features within this zone.\n\n**Final Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique='The answer is correct, but the explanation could be more concise. The student correctly identifies the second zone (Zone of Transition) as the area with low-income slums and ethnic ghettos. The student includes the causes of these features but can provide a more direct and less elaborate explanation. The answer can be more straightforward without losing essential elements. The final answer provided by the student is correct.'), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand the feedback. The professor wants a more concise explanation, while still including the essential elements. Here\'s a revised answer:\n\n**Revised Answer:**\n\nThe Burgess concentric zone model identifies the **second** zone, known as the "Zone of Transition," as the area containing low-income slums, ethnic ghettos, and general deterioration. This zone\'s proximity to the central business district and its constant state of change due to immigration and industrial encroachment contribute to these characteristics.\n\n**Final Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student's answer is incorrect. The zone containing low-income slums, ethnic ghettos, and general deterioration in Burgess's concentric zone model is the second zone, which the student correctly identified as the 'Zone of Transition'. However, the final answer provided by the student is '1', which corresponds to the 'Second' option. Thus, the final answer is correct and does not need modification."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand. The initial answer provided the correct zone, along with a reasonable explanation. The feedback confirms that the final answer (1, corresponding to the second zone) is correct. Therefore, no modification is needed.\n\n**Final Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student's reasoning is based on the assumption that the 'initial answer' was correct and that the feedback confirmed it. However, the student's reasoning doesn't explicitly state what the 'initial answer' or the 'feedback' were. Without knowing the content of the initial answer and feedback, it's impossible to confirm the student's reasoning. The student's final answer (1) seems plausible, but the reasoning lacks supporting evidence. The student should have included the initial answer and feedback to support the final answer."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand. The feedback highlights a crucial flaw in my previous response: it lacks supporting evidence and relies on assumptions. I need to explicitly state the initial answer, the feedback, and the reasoning process.\n\nHere\'s the breakdown, incorporating the feedback:\n\n**Initial Attempt (Hypothetical, as I don\'t have it):**\n\nLet\'s assume the initial attempt was something like:\n\n"The zone containing low-income slums, ethnic ghettos, and general deterioration is the third zone. This is the \'zone of transition\', where businesses and light manufacturing encroach on residential areas, leading to decline and the concentration of less affluent populations."\n\n**Feedback (Hypothetical):**\n\n"The initial answer is partially correct but needs refinement. While the \'zone of transition\' is relevant, the question specifically refers to the zone with the most concentrated issues like slums and ghettos. Consider where these populations initially settle and how the zones evolve."\n\n**Revised Reasoning:**\n\n1.  **Understanding Burgess\'s Model:** The Burgess model, also known as the concentric zone model, describes urban areas as a series of rings or zones radiating outwards from a central business district (CBD).\n2.  **Identifying the Problem Area:** The question asks about the zone with low-income slums, ethnic ghettos, and general deterioration. These are characteristics of areas where the housing is older, often subdivided, and less desirable. These zones also experience higher rates of poverty and crime.\n3.  **Analyzing the Zones:**\n    *   **Zone 1 (CBD):** The central business district, the core of the city.\n    *   **Zone 2 (Zone of Transition):** This zone immediately surrounds the CBD. It\'s characterized by a mix of industrial and residential uses, often containing older housing and, importantly, is where newly arrived immigrant groups and low-income populations often settle. It is this zone that typically contains the described characteristics.\n    *   **Zone 3 (Working-Class Homes):** This zone consists of working-class residences.\n    *   **Zone 4 (Higher-Class Residences):** The zone of higher-class residences.\n    *   **Zone 5 (Commuter Zone):** The commuter zone, farther away from the city center.\n4.  **Connecting the Concepts:** Based on the model and the description, the zone with the most significant concentration of these issues is the second zone, the "zone of transition". This zone is where the characteristics of low-income housing, ethnic ghettos, and general deterioration are most prevalent.\n5.  **Justification for Answer:** The characteristics mentioned in the question directly align with the description of the second zone in the Burgess model.\n\n**Final Answer:** 1\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student's reasoning is sound and demonstrates a good understanding of the Burgess model. The student correctly identifies the 'zone of transition' as the area most associated with the described characteristics. The answer is correct."), 'steps': 1}}
# {'research': {'answer': 'Okay, I understand. Based on the feedback, my initial reasoning was accurate, and the final answer is correct. The critical part was identifying the "zone of transition" as the correct answer. Here\'s the refined response, incorporating the feedback directly:\n\n**Final Answer:** 1\n\n**Reasoning:**\n\n1.  **Understanding the Question:** The question asks which zone in Burgess\'s concentric zone model contains low-income slums, ethnic ghettos, and general deterioration.\n2.  **Understanding Burgess\'s Model:** The Burgess model describes urban areas as a series of concentric rings. The key zones for this question are:\n    *   **Zone 1 (CBD):** The central business district.\n    *   **Zone 2 (Zone of Transition):** This zone surrounds the CBD and is characterized by a mix of industrial and residential uses. It often contains older housing, is where newly arrived immigrants and low-income populations settle, and is subject to encroachment from businesses and light manufacturing.\n    *   **Zone 3 (Working-Class Homes):** Residences for the working class.\n    *   **Zone 4 (Higher-Class Residences):** Higher-class residential areas.\n    *   **Zone 5 (Commuter Zone):** The commuter zone.\n3.  **Identifying the Correct Zone:** The "zone of transition" (Zone 2) is the area most associated with low-income slums, ethnic ghettos, and general deterioration. This is due to a combination of factors, including the age and quality of housing, the influx of new immigrant groups and low-income populations, and the encroachment of businesses and industry. These groups often settle in this zone upon arriving in the city due to the cheaper housing and proximity to the center of the city where they may find work.\n4.  **Conclusion:** The answer is 1, the second zone, which is the "zone of transition".\n'}}
# {'reflect': {'response': Response(answer=None, critique='The reasoning is sound and the answer is correct. The student has correctly identified the zone of transition as the correct answer and provided a good explanation of why. No improvements are needed.'), 'steps': 1}}
# {'research': {'answer': 'Okay, I\'m glad the feedback was positive. Since the feedback indicated no improvements were needed, the answer is already in excellent shape. Therefore, I\'ll simply reiterate the final answer and reasoning, confirming the understanding.\n\n**Final Answer:** 1\n\n**Reasoning:**\n\n1.  **Understanding the Question:** The question asks which zone in Burgess\'s concentric zone model contains low-income slums, ethnic ghettos, and general deterioration.\n2.  **Understanding Burgess\'s Model:** The Burgess model describes urban areas as a series of concentric rings. The key zones for this question are:\n    *   **Zone 1 (CBD):** The central business district.\n    *   **Zone 2 (Zone of Transition):** This zone surrounds the CBD and is characterized by a mix of industrial and residential uses. It often contains older housing, is where newly arrived immigrants and low-income populations settle, and is subject to encroachment from businesses and light manufacturing.\n    *   **Zone 3 (Working-Class Homes):** Residences for the working class.\n    *   **Zone 4 (Higher-Class Residences):** Higher-class residential areas.\n    *   **Zone 5 (Commuter Zone):** The commuter zone.\n3.  **Identifying the Correct Zone:** The "zone of transition" (Zone 2) is the area most associated with low-income slums, ethnic ghettos, and general deterioration. This is due to a combination of factors, including the age and quality of housing, the influx of new immigrant groups and low-income populations, and the encroachment of businesses and industry. These groups often settle in this zone upon arriving in the city due to the cheaper housing and proximity to the center of the city where they may find work.\n4.  **Conclusion:** The answer is 1, the second zone, which is the "zone of transition".\n'}}
# {'reflect': {'response': Response(answer=None, critique="The student's answer is correct, and the reasoning is well-explained and accurate. The student correctly identifies the Zone of Transition (Zone 2) as the area described in the question and provides a good explanation of the factors that characterize this zone. There is no need for improvement."), 'steps': 1}}
